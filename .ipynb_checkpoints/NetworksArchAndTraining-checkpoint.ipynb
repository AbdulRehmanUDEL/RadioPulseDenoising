# %%
## In this script we create the networks architecture and show how they can be trained.
# For properly training the networks you would need a large data.

from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Classifier:

# %%
## Importing libraries

import os

ABS_PATH_HERE = str(os.getcwd())

import tensorflow as tf
seed = 786
tf.keras.utils.set_random_seed(seed)
# tf.config.experimental.enable_op_determinism()

from tensorflow.keras import backend as K


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Concatenate, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback

# %%
## Function to normalize the traces in range [-1, 1]
def normalize_array(array):
    normalized_array = np.zeros_like(array)  # Create a new array to store normalized values
    scale_fac = []
    for i in range(array.shape[0]):  # Iterate over samples/events
        max_value = np.max(np.abs(array[i]))  # Calculate the maximum value across both channels
        
        if max_value != 0:  # Avoid division by zero
            normalized_sample = array[i] / max_value
            normalized_array[i] = normalized_sample
        else:
            print("Max vlue 0 encountered at index :", i)
        scale_fac.append(max_value)
    return normalized_array, scale_fac


## This class can change the learning rate with the given factor and patience
class LearningRateScheduler(Callback):
    def __init__(self, factor, patience):
        super(LearningRateScheduler, self).__init__()
        self.factor = factor
        self.patience = patience
        self.wait = 0
        self.best_val_loss = float('inf')

    def on_epoch_end(self, epoch, logs=None):
        current_val_loss = logs.get('val_loss')
        
        if current_val_loss < self.best_val_loss:
            self.best_val_loss = current_val_loss
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                # old_lr = float(K.get_value(self.model.optimizer.lr))
                old_lr = float(self.model.optimizer.learning_rate.numpy())
                new_lr = old_lr * self.factor
                # K.set_value(self.model.optimizer.lr, new_lr)
                self.model.optimizer.learning_rate.assign(new_lr)
                self.wait = 0
                print(f"Reducing learning rate to {new_lr}")

# %%
## Loading the data for Classifier

# Note: If you get the "FileNotFoundError:" make sure that the notebook "DataReshapingForNetworks" ran properly.

## Provide the data directory
DataDir = ABS_PATH_HERE + "/data/TstTrain_Classifier"

## Provide the trainig data
x_train = np.load(DataDir + "/Traces_train.npy")  
x_test = np.load(DataDir + "/Traces_test.npy")

## Provide labels (0 for noise-only traces and 1 for signal-plus-noise traces)
y_train = np.load(DataDir + "/Labels_train.npy")
y_test = np.load(DataDir + "/Labels_test.npy")


### Normalizing
x_train, scalefac = normalize_array(x_train)
x_test, scalefacT = normalize_array(x_test)

# %%
print(f'Shape of x_train {x_train.shape}')
print(f'Shape of x_test {x_test.shape}')
# Out:
# Shape of x_train (700, 1000, 2)
# Shape of x_test (300, 1000, 2)

# %%
print(f"Total size in Mbs = {x_train.nbytes/10**6}")
# Out:
# Total size in Mbs = 11.2

# %%
## Creating the Classifier network

def CreateModel(KS, FIL, Layers, lr=5e-3):

    # Define the input shape for each polarization
    input_shape = (1000, 2)  # 2 channels, 1 for each polarization

    # Define the input layer
    input_layer = Input(shape=input_shape)
    x = input_layer

    # Convolutional layers
    for i in range(Layers):
        x = Conv1D(filters=FIL, kernel_size=KS, activation='relu', padding='same')(x)
        x = MaxPooling1D(pool_size=2)(x)

    # Flatten the pooled output
    x = Flatten()(x)
    
    ## Adding more dense layers didn't help imporve results, but can be added like below
#     x = Dense(64, activation='relu')(x)
    output = Dense(1, activation='sigmoid')(x)

    # Create the model
    model = Model(inputs=input_layer, outputs=output)

    # Compile the model, with defined loss and optimizer
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='mse', metrics=['accuracy'])
    
    return model

# %%
ModelsDir = os.path.join(ABS_PATH_HERE, "temp_models")

# Create the directory (and parents) only if it doesn't already exist
os.makedirs(ModelsDir, exist_ok=True)

### Training Settings
## Learning rate schesuler
lr_scheduler = LearningRateScheduler(factor=0.5, patience=5)

## Early Stopping Criterion
es = EarlyStopping(monitor='val_loss', mode='min',restore_best_weights=True, verbose=1, patience=5)

## Model checkpoints
mc = ModelCheckpoint(filepath= ModelsDir+'/Classifier.keras',
                                    monitor = 'val_loss', mode = 'min', verbose=1, save_best_only=True)

## Create networks
autoencoder = CreateModel(KS=33, FIL=6, Layers=3, lr=1e-4)

## Training (only doing for 10 epochs here)
history = autoencoder.fit(x_train, y_train,
                          epochs=20,
                          batch_size=100,
                          shuffle=True,
                          validation_data=(x_test, y_test),
                          callbacks=[lr_scheduler, es, mc])
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5009 - loss: 0.2468
# Epoch 1: val_loss improved from inf to 0.24928, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Classifier.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.5008 - loss: 0.2467 - val_accuracy: 0.5000 - val_loss: 0.2493
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5009 - loss: 0.2450
# Epoch 2: val_loss improved from 0.24928 to 0.24852, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Classifier.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.5008 - loss: 0.2450 - val_accuracy: 0.5000 - val_loss: 0.2485
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5009 - loss: 0.2444
# Epoch 3: val_loss improved from 0.24852 to 0.24839, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Classifier.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.5008 - loss: 0.2444 - val_accuracy: 0.5000 - val_loss: 0.2484
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5009 - loss: 0.2442
# Epoch 4: val_loss did not improve from 0.24839
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.5008 - loss: 0.2442 - val_accuracy: 0.5033 - val_loss: 0.2484
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5009 - loss: 0.2440
# Epoch 5: val_loss did not improve from 0.24839
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.5008 - loss: 0.2440 - val_accuracy: 0.5033 - val_loss: 0.2485
# Epoch 6/20
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5011 - loss: 0.2437
# Epoch 6: val_loss did not improve from 0.24839
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.5008 - loss: 0.2438 - val_accuracy: 0.5033 - val_loss: 0.2486
# Epoch 7/20
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5011 - loss: 0.2435
# Epoch 7: val_loss did not improve from 0.24839
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5008 - loss: 0.2435 - val_accuracy: 0.5033 - val_loss: 0.2487
# Epoch 8/20
# Reducing learning rate to 4.999999873689376e-05 0s 66ms/step - accuracy: 0.5009 - loss: 0.2432
#
# Epoch 8: val_loss did not improve from 0.24839
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.5008 - loss: 0.2432 - val_accuracy: 0.5033 - val_loss: 0.2488
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
train_loss = history.history[list(history.history.keys())[0]]
test_loss = history.history[list(history.history.keys())[2]]

train_accu = history.history[list(history.history.keys())[1]]
test_accu = history.history[list(history.history.keys())[3]]

# %%
plt.plot(train_loss, label="train_loss")
plt.plot(test_loss, label="test_loss")
plt.legend()
plt.figure()
plt.plot(train_accu, label="train_accu")
plt.plot(test_accu, label="test_accu")
plt.legend();

# %% [markdown]
# # Denoiser

# %%
import tensorflow as tf
seed = 786
tf.keras.utils.set_random_seed(seed)
# tf.config.experimental.enable_op_determinism()

from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D, Concatenate, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.optimizers import Adam, RMSprop


def normalize_deno_array(array, y_array):
    normalized_array = np.zeros_like(array)  # Create a new array to store normalized values
    normalized_y_array = np.zeros_like(array)  
    
    scale_fac = []
    for i in range(array.shape[0]):  # Iterate over samples/events
        max_value = np.max(np.abs(array[i]))  # Calculate the maximum value across both channels
        
        if max_value != 0:  # Avoid division by zero
            normalized_sample = array[i] / max_value
            normalized_array[i] = normalized_sample
            
            ## Normalizing labels
            normalized_y_sample = y_array[i] / max_value
            normalized_y_array[i] = normalized_y_sample
            
        else:
            print("Max vlue 0 encountered at index :", i)
        scale_fac.append(max_value)
    return normalized_array, normalized_y_array, scale_fac

# %%
## Loading data

## Provide the denoiser data directory
DataDir = ABS_PATH_HERE + "/data/TstTrain_Denoiser"

# Provide training data
x_train = np.load(DataDir + "/Noisy_train.npy")
x_test = np.load(DataDir + "/Noisy_test.npy")

# Provide labels (pure signal traces)
y_train = np.load(DataDir + "/Signals_train.npy")
y_test = np.load(DataDir + "/Signals_test.npy")

### Normalizing
x_train, y_train, scalefac = normalize_deno_array(x_train, y_train)
x_test, y_test, scalefacT = normalize_deno_array(x_test, y_test)

# %%
class LearningRateScheduler(Callback):
    def __init__(self, factor, patience):
        super(LearningRateScheduler, self).__init__()
        self.factor = factor
        self.patience = patience
        self.wait = 0
        self.best_val_loss = float('inf')

    def on_epoch_end(self, epoch, logs=None):
        current_val_loss = logs.get('val_loss')
        
        if current_val_loss < self.best_val_loss:
            self.best_val_loss = current_val_loss
            self.wait = 0
        else:
            self.wait += 1
            if self.wait >= self.patience:
                # old_lr = float(K.get_value(self.model.optimizer.lr))
                old_lr = float(self.model.optimizer.learning_rate.numpy())
                new_lr = old_lr * self.factor
                # K.set_value(self.model.optimizer.lr, new_lr)
                self.model.optimizer.learning_rate.assign(new_lr)
                self.wait = 0
                print(f"Reducing learning rate to {new_lr}")

def CorrCoeff(y_true, y_pred):
    x = y_true
    y = y_pred
    mx = K.mean(x)
    my = mx
    xm, ym = x-mx, y-my
    r_num = K.sum(tf.multiply(xm,ym))
    r_den = K.sqrt(tf.multiply(K.sum(K.square(xm)), K.sum(K.square(ym))))
    r = r_num / r_den
    return r
# Custom correlation metric
def CC2(y_true, y_pred):
    def pearson_correlation(x, y):
        mean_x = K.mean(x)
        mean_y = K.mean(y)
        cov_xy = K.sum((x - mean_x) * (y - mean_y))
        std_x = K.sqrt(K.sum(K.square(x - mean_x)))
        std_y = K.sqrt(K.sum(K.square(y - mean_y)))
        correlation = cov_xy / (std_x * std_y)
        return correlation

    correlation = tf.py_function(pearson_correlation, [y_true, y_pred], tf.float32)
    return correlation


def Denoiser(fil, ks, lr=1e-3):
    input_shape = (1000, 2)

    # Encoder architecture
    input_layer = Input(shape=input_shape)
    
    x = Conv1D(fil, ks, activation='relu', padding='same')(input_layer)
    x = MaxPooling1D(2, padding='same')(x)
    x = Conv1D(fil, ks, activation='relu', padding='same')(x)
    x = MaxPooling1D(2, padding='same')(x)
    x = Conv1D(fil, ks, activation='relu', padding='same')(x)
    x = MaxPooling1D(2, padding='same')(x)

    # Decoder architecture
    x = Conv1D(fil, ks, activation='relu', padding='same')(x)
    x = UpSampling1D(2)(x)
    x = Conv1D(fil, ks, activation='relu', padding='same')(x)
    x = UpSampling1D(2)(x)
    x = Conv1D(fil, ks, activation='relu', padding='same')(x)
    x = UpSampling1D(2)(x)

    # Final layer
    decoded = Conv1D(2, ks, activation='linear', padding='same')(x)

    # Create the autoencoder model
    autoencoder = Model(input_layer, decoded)

    # Compile the model
    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr), loss='mse', metrics=[CorrCoeff])
    
    return autoencoder

# %%
# Directory to store the checkpoint models
ModelsDir = os.path.join(ABS_PATH_HERE, "temp_models")

# Create the directory (and parents) only if it doesn't already exist
os.makedirs(ModelsDir, exist_ok=True)

### Training
lr_scheduler = LearningRateScheduler(factor=0.5, patience=5)
es = EarlyStopping(monitor='val_loss', mode='min',restore_best_weights=True, verbose=1, patience=5)
mc = ModelCheckpoint(filepath=ModelsDir+'/Denoiser.keras',
                                    monitor = 'val_loss', mode = 'min', verbose=1, save_best_only=True)

autoencoder = Denoiser(fil=12, ks=33, lr=1e-4)

history = autoencoder.fit(x_train, y_train, 
                          epochs=20, 
                          batch_size=100, 
                          shuffle=True,
                          validation_data=(x_test, y_test), 
                          callbacks=[lr_scheduler, es, mc])
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - corr_coeff: 8.5116e-04 - loss: 0.0030
# Epoch 1: val_loss improved from inf to 0.00295, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 410ms/step - corr_coeff: 8.8427e-04 - loss: 0.0029 - val_corr_coeff: 0.0022 - val_loss: 0.0029
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - corr_coeff: 0.0011 - loss: 0.0026
# Epoch 2: val_loss improved from 0.00295 to 0.00285, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - corr_coeff: 0.0011 - loss: 0.0026 - val_corr_coeff: 0.0026 - val_loss: 0.0029
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - corr_coeff: 0.0012 - loss: 0.0025
# Epoch 3: val_loss improved from 0.00285 to 0.00283, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - corr_coeff: 0.0012 - loss: 0.0025 - val_corr_coeff: 0.0028 - val_loss: 0.0028
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - corr_coeff: 0.0010 - loss: 0.0025
# Epoch 4: val_loss improved from 0.00283 to 0.00283, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - corr_coeff: 0.0010 - loss: 0.0025 - val_corr_coeff: 0.0029 - val_loss: 0.0028
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - corr_coeff: 0.0012 - loss: 0.0025
# Epoch 5: val_loss improved from 0.00283 to 0.00283, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - corr_coeff: 0.0012 - loss: 0.0025 - val_corr_coeff: 0.0032 - val_loss: 0.0028
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - corr_coeff: 0.0014 - loss: 0.0025
# Epoch 6: val_loss improved from 0.00283 to 0.00282, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - corr_coeff: 0.0014 - loss: 0.0025 - val_corr_coeff: 0.0037 - val_loss: 0.0028
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - corr_coeff: 0.0019 - loss: 0.0025
# Epoch 7: val_loss improved from 0.00282 to 0.00282, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step - corr_coeff: 0.0019 - loss: 0.0025 - val_corr_coeff: 0.0043 - val_loss: 0.0028
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - corr_coeff: 0.0023 - loss: 0.0025
# Epoch 8: val_loss improved from 0.00282 to 0.00282, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step - corr_coeff: 0.0023 - loss: 0.0025 - val_corr_coeff: 0.0050 - val_loss: 0.0028
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - corr_coeff: 0.0026 - loss: 0.0025
# Epoch 9: val_loss improved from 0.00282 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - corr_coeff: 0.0026 - loss: 0.0025 - val_corr_coeff: 0.0055 - val_loss: 0.0028
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - corr_coeff: 0.0029 - loss: 0.0025
# Epoch 10: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - corr_coeff: 0.0029 - loss: 0.0025 - val_corr_coeff: 0.0058 - val_loss: 0.0028
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - corr_coeff: 0.0033 - loss: 0.0025
# Epoch 11: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - corr_coeff: 0.0033 - loss: 0.0025 - val_corr_coeff: 0.0062 - val_loss: 0.0028
# Epoch 12/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - corr_coeff: 0.0036 - loss: 0.0025
# Epoch 12: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - corr_coeff: 0.0037 - loss: 0.0025 - val_corr_coeff: 0.0063 - val_loss: 0.0028
# Epoch 13/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - corr_coeff: 0.0038 - loss: 0.0025
# Epoch 13: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step - corr_coeff: 0.0038 - loss: 0.0025 - val_corr_coeff: 0.0065 - val_loss: 0.0028
# Epoch 14/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - corr_coeff: 0.0041 - loss: 0.0025
# Epoch 14: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - corr_coeff: 0.0041 - loss: 0.0025 - val_corr_coeff: 0.0065 - val_loss: 0.0028
# Epoch 15/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - corr_coeff: 0.0042 - loss: 0.0025
# Epoch 15: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 296ms/step - corr_coeff: 0.0043 - loss: 0.0025 - val_corr_coeff: 0.0065 - val_loss: 0.0028
# Epoch 16/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - corr_coeff: 0.0045 - loss: 0.0025
# Epoch 16: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - corr_coeff: 0.0046 - loss: 0.0025 - val_corr_coeff: 0.0066 - val_loss: 0.0028
# Epoch 17/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - corr_coeff: 0.0047 - loss: 0.0025
# Epoch 17: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - corr_coeff: 0.0048 - loss: 0.0025 - val_corr_coeff: 0.0068 - val_loss: 0.0028
# Epoch 18/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - corr_coeff: 0.0049 - loss: 0.0025
# Epoch 18: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 284ms/step - corr_coeff: 0.0050 - loss: 0.0025 - val_corr_coeff: 0.0069 - val_loss: 0.0028
# Epoch 19/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - corr_coeff: 0.0051 - loss: 0.0025
# Epoch 19: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - corr_coeff: 0.0052 - loss: 0.0025 - val_corr_coeff: 0.0070 - val_loss: 0.0028
# Epoch 20/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - corr_coeff: 0.0053 - loss: 0.0025
# Epoch 20: val_loss improved from 0.00281 to 0.00281, saving model to /home/arehman/RadioCNN/RadioPulseDenoising/temp_models/Denoiser.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step - corr_coeff: 0.0054 - loss: 0.0025 - val_corr_coeff: 0.0071 - val_loss: 0.0028
# Restoring model weights from the end of the best epoch: 20.

# %%
history.history.keys()
# Out:
# dict_keys(['corr_coeff', 'loss', 'val_corr_coeff', 'val_loss'])

# %%
history.history.keys()
train_loss = history.history[list(history.history.keys())[0]]
test_loss = history.history[list(history.history.keys())[2]]

train_accu = history.history[list(history.history.keys())[1]]
test_accu = history.history[list(history.history.keys())[3]]

# %%
plt.plot(train_loss, label="train_loss")
plt.plot(test_loss, label="test_loss")
plt.legend()
plt.figure()
plt.plot(train_accu, label="train_accu")
plt.plot(test_accu, label="test_accu")
plt.legend();
